# %% [markdown]
# # Prototype Notebook - Quick Experimentation
#
# Notebook para experimentación rápida y prototipado de nuevas ideas.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path().resolve().parent / 'src'))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from pneumonia.data import load_training_data, preprocess_data
from pneumonia.utils import setup_logger

logger = setup_logger(__name__)
# %matplotlib inline
plt.style.use('seaborn-v0_8-darkgrid')

# %% [markdown]
# ## Idea 1: Exploración de Nuevas Features
#
# Experimenta con ingeniería de features aquí

# %%
# Cargar datos
df = load_training_data(
    table_name="training_data",
    limit=1000
)

print(f"Dataset shape: {df.shape}")
df.head()

# %%
# TODO: Crear nuevas features aquí
# Ejemplo:
# df['feature1_log'] = np.log1p(df['feature1'])
# df['feature_interaction'] = df['feature1'] * df['feature2']

print("Nuevas features creadas")

# %% [markdown]
# ## Idea 2: Testing de Hiperparámetros
#
# Experimenta con diferentes configuraciones de modelos

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# TODO: Configurar grid de hiperparámetros
param_grid = {
    'n_estimators': [50, 100],
    'max_depth': [5, 10, 15],
    'min_samples_split': [2, 5]
}

# grid_search = GridSearchCV(
#     RandomForestClassifier(random_state=42),
#     param_grid,
#     cv=3,
#     n_jobs=-1
# )

print("Grid search configurado (comentado)")

# %% [markdown]
# ## Idea 3: Análisis Específico
#
# Realiza análisis custom aquí

# %%
# TODO: Escribir análisis aquí
# Ejemplos:
# - Visualizaciones específicas
# - Comparación de subgrupos
# - Validación de hipótesis

print("Espacio para análisis custom")

# %% [markdown]
# ## Notas Importantes
#
# - Este notebook es para experimentación rápida
# - Código probado debe moverse a módulos en `src/pneumonia/`
# - Mantener este notebook limpio para futuros experimentos
